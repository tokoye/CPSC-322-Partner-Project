# %%
import importlib
import mysklearn.plot_utils as plot_utils

import importlib
import mysklearn.myutils
importlib.reload(mysklearn.myutils)
import mysklearn.myutils as myutils
# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 
import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
import os
import matplotlib.pyplot as plt


## follow pa3
# Out:
# Traceback (most recent call last):
#
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-c91797cfc5ed>", line 2, in <module>
#     import mysklearn.plot_utils as plot_utils
#
#   File "/home/CPSC-322-Partner-Project/mysklearn/plot_utils.py", line 103
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Spotify Classification
#
# The accuracies of oth classifiers are the same

# %%
import importlib
import mysklearn.myutils
importlib.reload(mysklearn.myutils)
import mysklearn.myutils as myutils
# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 
import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
import os

#General EDA Questions
importlib.reload(utils)                 
table = utils.table_setUp("tracks_data.txt")

# Question 1
cols_to_plot = ["danceability","energy","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"]
totals_list = utils.pie_chart_dataPrep(table, cols_to_plot)
print("\n")
print("QUESTION 1 NUMBERS: ", cols_to_plot, totals_list)
print("\n")

# Question 3
print("QUESTION 3 danceability ratings in comparison to energy:")
importlib.reload(mypytable) 
importlib.reload(plot_utils)

mypytable.MyPyTable.remove_rows_with_missing_values(table)  

danceability_column_list = mypytable.MyPyTable.get_column(table, "Danceability")  
energy_column_list = mypytable.MyPyTable.get_column(table, "Energy") 
new_energy_list = utils.steal(energy_column_list, '%', 10) 
plot_utils.histogram("Danceability", danceability_column_list)
plot_utils.histogram("Energy", new_energy_list)



# Question 4
print("\n")
print("QUESTION 4 Regression and Covariance: ")

m, b, regression, covariance = utils.scatter_plotPrep(table, danceability_column_list, new_energy_list)
plot_utils.scatter_with_linear_regr(danceability_column_list, new_energy_list, m, b, regression, covariance, "Danceability", "Energy")




#not very predictive, lets try different attributes

# Danceability = tracks.get_column('danceability')
# Instrumentals = tracks.get_column('instrumentalness')
# Tempo = tracks.get_column('tempo')

# x_train = [[Danceability[i],Instrumentals[i],Tempo[i]] for i in range(len(Danceability))]
# y_train = tracks.get_column('popularity')

# train_folds, test_folds = myevaluation.stratified_kfold_cross_validation(x_train, y_train, 10)
# x_train2, y_train2, x_test2, y_test2 = myutils.folds_to_train(x_train, y_train, train_folds, test_folds)

# tree = MyDecisionTreeClassifier()
# tree.fit(x_train2, y_train2)
# pred2 = tree.predict(x_test2)
# accuracy2 = myutils.get_accuracy(y_test2, pred2)
# print("===========================================")
# print("Predictive Accuracy")
# print("===========================================")
# print('Stratified 10-Fold Cross Validation')
# print('Decision Tree: accuracy =', accuracy2, 'error rate = ', (1-accuracy2))

# nb = MyNaiveBayesClassifier()
# nb.fit(x_train2, y_train2)
# pred2 = nb.predict(x_test2)
# accuracy2 = myutils.get_accuracy(y_test2, pred2)
# print('Naive Bayes: accuracy =', accuracy2, 'error rate = ', (1-accuracy2))

# z = MyZeroClassifier()
# z.fit(y_train1)
# predz = z.predict()

# rc = MyRandomClassifier()
# rc.fit(y_train2)
# predr = rc.predict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b2f08f490353> in <module>
#      16
#      17 #General EDA Questions
# ---> 18 importlib.reload(utils)
#      19 table = utils.table_setUp("tracks_data.txt")
#      20
#
# NameError: name 'utils' is not defined

# %% [markdown]
# ### Confusion Matrix / Decision Rules

# %%
import importlib
import mysklearn.myutils
importlib.reload(mysklearn.myutils)
import mysklearn.myutils as myutils
# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 
import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier, MyZeroClassifier, MyRandomClassifier
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
import os

fname = os.path.join("input_data", "tracks_data.txt")
tracks = MyPyTable().load_from_file(fname)

Danceability = tracks.get_column('danceability')
Energy = tracks.get_column('energy')
Speechiness = tracks.get_column('speechiness')
Acousticness = tracks.get_column('acousticness')
Instrumentals = tracks.get_column('instrumentalness')
Liveliness = tracks.get_column('liveness')
Valence = tracks.get_column('valence')
# Tempo = tracks.get_column('tempo')
# Duration = tracks.get_column('duration_ms')


y_train = tracks.get_column('popularity')
x_train = [[Danceability[i],Energy[i],Speechiness[i],Acousticness[i],Energy[i],Instrumentals[i],Liveliness[i],Valence[i]] for i in range(len(Energy))]


train_folds, test_folds = myevaluation.stratified_kfold_cross_validation(x_train, y_train, 10)
x_train2, y_train2, x_test2, y_test2 = myutils.folds_to_train(x_train, y_train, train_folds, test_folds)

# tree = MyDecisionTreeClassifier()
# tree.fit(x_train2, y_train2)
# pred2 = tree.predict(x_test2)
# accuracy2 = myutils.get_accuracy(y_test2, pred2)

# print("===========================================")
# print("Predictive Accuracy")
# print("===========================================")
# print('Stratified 10-Fold Cross Validation')

# print('Decision Tree: accuracy =', accuracy2, 'error rate = ', (1-accuracy2))
nb = MyNaiveBayesClassifier()
nb.fit(x_train2, y_train2)
pred2 = nb.predict(x_test2)
accuracy2 = myutils.get_accuracy(y_test2, pred2)

print('Naive Bayes: accuracy =', accuracy2, 'error rate = ', (1-accuracy2))

z = MyZeroClassifier()
z.fit(y_train)
predz = z.predict(y_test2)
accuracyz = myutils.get_accuracy(y_test2, predz)
print('Zero: accuracy =', accuracyz, 'error rate = ', (1-accuracyz))
# Out:
# -----------------------------------------------------------------
# AttributeError                  Traceback (most recent call last)
# <ipython-input-2-f497afe9f7ca> in <module>
#       1 import importlib
# ----> 2 import mysklearn.myutils
#       3 importlib.reload(mysklearn.myutils)
#       4 import mysklearn.myutils as myutils
#       5 # uncomment once you paste your mypytable.py into mysklearn package
#
# /home/CPSC-322-Partner-Project/mysklearn/myutils.py in <module>
#      16
#      17 import mysklearn.myutils
# ---> 18 importlib.reload(mysklearn.myutils)
#      19 import mysklearn.myutils as utils
#      20
#
# AttributeError: module 'mysklearn' has no attribute 'myutils'

# %%
import importlib
import mysklearn.myutils
importlib.reload(mysklearn.myutils)
import mysklearn.myutils as myutils
# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 
import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
import os
import random

fname = os.path.join("input_data", "tracks_data.txt")
tracks = MyPyTable().load_from_file(fname)
Danceability = tracks.get_column('danceability')
Energy = tracks.get_column('energy')
Speechiness = tracks.get_column('speechiness')
Acousticness = tracks.get_column('acousticness')
Instrumentals = tracks.get_column('instrumentalness')
Liveliness = tracks.get_column('liveness')
Valence = tracks.get_column('valence')


x_train = [[Energy[i],Speechiness[i],Acousticness[i],Energy[i],Instrumentals[i],Liveliness[i],Valence[i]] for i in range(len(Energy))]
y_train = Danceability



print(myutils.bagging(x_train, y_train, 20, 7, 2))
# Out:
# 0.4866412213740458
