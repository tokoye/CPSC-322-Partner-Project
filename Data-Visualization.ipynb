# %%
# some useful mysklearn package import statements and reloads
import importlib

import mysklearn.myutils
importlib.reload(mysklearn.myutils)
import mysklearn.myutils as myutils

# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
from mysklearn.mypytable import MyPyTable 

import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier

import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation

# %% [markdown]
# # Auto Classification
# Create a decision tree classifier that predicts mpg rankings (given in PA2) from the cylinders, weight, and model year attributes.

# %% [markdown]
# ### Decision Tree classifier using stratified k-fold cross-validation (with k = 10)
# The Decision Tree was about 2.8% more accurate than the Naive Bayes classifier.

# %%
import mysklearn.plot_utils as plot_utils
import importlib
import mysklearn
import mysklearn.myutils as myutils
importlib.reload(mysklearn.myutils)
# uncomment once you paste your mypytable.py into mysklearn package
import mysklearn.mypytable
importlib.reload(mysklearn.mypytable)
import mysklearn.mypytable as mypytable
import mysklearn.myclassifiers
importlib.reload(mysklearn.myclassifiers)
from mysklearn.myclassifiers import MyKNeighborsClassifier, MySimpleLinearRegressor, MyNaiveBayesClassifier, MyDecisionTreeClassifier
import mysklearn.myevaluation
importlib.reload(mysklearn.myevaluation)
import mysklearn.myevaluation as myevaluation
import os
import matplotlib.pyplot as plt

fname = os.path.join("input_data", "tracks_data.txt")
tracks = mypytable.MyPyTable().load_from_file(fname)
Danceability = tracks.get_column('danceability')
Energy = tracks.get_column('energy')
Speechiness = tracks.get_column('speechiness')
Acousticness = tracks.get_column('acousticness')
Instrumentals = tracks.get_column('instrumentalness')
Liveliness = tracks.get_column('liveness')
Valence = tracks.get_column('valence')
Tempo = tracks.get_column('tempo')
Duration = tracks.get_column('duration_ms')
Popularity = tracks.get_column('popularity')

importlib.reload(myutils)                 
table = myutils.table_setUp("tracks_data.txt")

cols_to_plot = ["energy","speechiness","acousticness","instrumentalness","liveness","valence","tempo","duration_ms"]
y = mypytable.MyPyTable.get_column(table, "danceability")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "danceability", col)

# %% [markdown]
# ### Confusion Matrix / Decision Tree Rules

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["duration_ms","speechiness","acousticness","instrumentalness","liveness","valence","tempo","danceability"]
y = mypytable.MyPyTable.get_column(table, "energy")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "energy", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["energy","speechiness","acousticness","instrumentalness","liveness","valence","tempo","danceability"]
y = mypytable.MyPyTable.get_column(table, "duration_ms")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "duration_ms", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

#get all the cols
#for each col, get each of the possible values, and their counts
    # values, counts = myutils.get_freq_str(col) #values [very_low, low, medium, high, very_high], counts = [1000,...]

cols_to_plot = ["energy","speechiness","acousticness","instrumentalness","liveness","valence","tempo","danceability","duration_ms"]
y = mypytable.MyPyTable.get_column(table, "popularity")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "popularity", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["energy","speechiness","acousticness","instrumentalness","duration_ms","valence","tempo","danceability"]
y = mypytable.MyPyTable.get_column(table, "liveness")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "liveness", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["energy","speechiness","acousticness","instrumentalness","duration_ms","valence","liveness","danceability"]
y = mypytable.MyPyTable.get_column(table, "tempo")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "tempo", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["energy","tempo","acousticness","instrumentalness","duration_ms","valence","liveness","danceability"]
y = mypytable.MyPyTable.get_column(table, "speechiness")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "speechiness", col)

# %%
importlib.reload(mypytable)
importlib.reload(myutils)   
importlib.reload(plot_utils)

cols_to_plot = ["energy","tempo","speechiness","instrumentalness","duration_ms","valence","liveness","danceability"]
y = mypytable.MyPyTable.get_column(table, "acousticness")

for col in cols_to_plot:
    x = mypytable.MyPyTable.get_column(table, col)
    m, b, regression, covariance = myutils.scatter_plotPrep(table, x,y)
    plot_utils.scatter_with_linear_regr(x, y, m, b, regression, covariance, "acousticness", col)
